# %% [markdown]
# <a href="https://colab.research.google.com/github/pritesh2292/play-store-app-review-analysis/blob/main/Pritesh's_Copy_of_Play_Store_App_Review_Analysis_Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <b> The Play Store apps data has enormous potential to drive app-making businesses to success. Actionable insights can be drawn for developers to work on and capture the Android market. </b>
#
# ## <b> Each app (row) has values for catergory, rating, size, and more. Another dataset contains customer reviews of the android apps.</b>
#
# ## <b> Explore and analyze the data to discover key factors responsible for app engagement and success. </b>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path_of_playstore_data = '/content/drive/MyDrive/Copy of Play Store Data.csv'
ud_df=pd.read_csv(path_of_playstore_data)
ud_df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
ud_df.head(10)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN     4.4
# 6            Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                   Infinite Painter  ART_AND_DESIGN     4.1
# 8                               Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                      Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# ...

# %%
ud_df.tail(10)
# Out:
#                                                  App             Category  \
# 10831                       payermonstationnement.fr  MAPS_AND_NAVIGATION
# 10832                                       FR Tides              WEATHER
# 10833                                    Chemin (fr)  BOOKS_AND_REFERENCE
# 10834                                  FR Calculator               FAMILY
# 10835                                       FR Forms             BUSINESS
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10831     NaN      38                9.8M       5,000+  Free     0
# ...

# %%
ud_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
ud_df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
ud_df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
#we are fixing rating column which contains a total of 1474 of missing values
modeValueRating = ud_df['Rating'].mode()

# %%
ud_df['Rating'].fillna(value=modeValueRating[0], inplace = True)

# %%
ud_df['Installs'] = ud_df.Installs.apply(lambda x: x.strip('+'))  # remove + 
ud_df['Installs'] = ud_df.Installs.apply(lambda x: x.replace(',',''))

# %%
ud_df['Installs'] = ud_df.Installs.replace('Free', np.NaN)

# %%
ud_df['Installs'] = pd.to_numeric(ud_df['Installs'])

# %%
ud_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          10841 non-null  float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10840 non-null  float64
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(2), object(11)
# memory usage: 1.1+ MB

# %%
ud_df.dropna(subset = ['Size'], inplace=True)

# %%
ud_df['Price'].value_counts()
# Out:
# 0         10040
# $0.99       148
# $2.99       129
# $1.99        73
# $4.99        72
#           ...
# $1.75         1
# $14.00        1
# $4.85         1
# $46.99        1
# $1.04         1
# Name: Price, Length: 93, dtype: int64

# %%
ud_df['Price'] = ud_df.Price.apply(lambda x: x.strip('$'))

# %%
ud_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          10841 non-null  float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10840 non-null  float64
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(2), object(11)
# memory usage: 1.2+ MB

# %%
 # 0 need to be remove from the Type column
ud_df.loc[ud_df['Type'] == '0'].index.values
# Out:
# array([10472])

# %%
ud_df.drop(ud_df.index[10472], inplace=True)

# %%
playstore_user_review = '/content/drive/MyDrive/Copy of User Reviews.csv'
ud_df_review = pd.read_csv(playstore_user_review)
ud_df_review
# Out:
#                                App  \
# 0            10 Best Foods for You
# 1            10 Best Foods for You
# 2            10 Best Foods for You
# 3            10 Best Foods for You
# 4            10 Best Foods for You
# ...                            ...
# 64290  Houzz Interior Design Ideas
# 64291  Houzz Interior Design Ideas
# 64292  Houzz Interior Design Ideas
# 64293  Houzz Interior Design Ideas
# 64294  Houzz Interior Design Ideas
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 2                                                    NaN       NaN
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# ...                                                  ...       ...
# ...

# %%
ud_df_review.drop_duplicates()
# Out:
#                                   App  \
# 0               10 Best Foods for You
# 1               10 Best Foods for You
# 2               10 Best Foods for You
# 3               10 Best Foods for You
# 4               10 Best Foods for You
# ...                               ...
# 64223  Housing-Real Estate & Property
# 64226  Housing-Real Estate & Property
# 64227  Housing-Real Estate & Property
# 64230  Housing-Real Estate & Property
# 64236     Houzz Interior Design Ideas
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 2                                                    NaN       NaN
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# ...                                                  ...       ...
# ...

# %%
ud_df_review.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %%
x = ud_df['Content Rating'].value_counts().index
y = ud_df['Content Rating'].value_counts()
xsis = []
ysis = []
for i in range(len(x)):
  xsis.append(x[i])
  ysis.append(y[i])

# %%
plt.figure(figsize=(12,10))
plt.bar(xsis, ysis, width=0.8,  alpha=0.8)
plt.title('Content Rating', size=20)
plt.xlabel('Content Rating')
plt.ylabel('App(count)')
plt.show()

# %%
def findtop10incategory(str):
    str = str.upper()
    top10 = ud_df[ud_df['Category'] == str]
    top10apps = top10.sort_values(by='Installs', ascending=False).head(10)
    # Top_Apps_in_art_and_design
    plt.figure(figsize=(15,12))
    plt.title('Top 10 Installed Apps',size = 20);    
    graph = sns.barplot(x = top10apps.App, y = top10apps.Installs)
    graph.set_xticklabels(graph.get_xticklabels(), rotation= 45, horizontalalignment='right');

# %%
y = ud_df['Category'].value_counts().index
x = ud_df['Category'].value_counts()
xsis = []
ysis = []
for i in range(len(x)):
    xsis.append(x[i])
    ysis.append(y[i])

# %%
plt.figure(figsize=(18,13))
plt.xlabel("Count")
plt.ylabel("Category")

graph = sns.barplot(x = xsis, y = ysis, palette= "husl")
graph.set_title("Top categories on Google Playstore", fontsize = 25);

# %%
top10PaidApps = ud_df[ud_df['Type'] == 'Paid'].sort_values(by='Price', ascending=False).head(11)

# %%
top10PaidApps_df = top10PaidApps[['App', 'Installs']]
top10PaidApps_df
# Out:
#                                   App  Installs
# 4938                        Pocket AC    1000.0
# 6205                 Baldur's Gate II   50000.0
# 8721                 DRAGON QUEST III   10000.0
# 8733    CHRONO TRIGGER (Upgrade Ver.)  100000.0
# 7798      Jeppesen CR Flight Computer     100.0
# 7893    Abdominal CT Sectional Walker     100.0
# 7898        Chest CT Sectional Walker     100.0
# 10006             XCOM®: Enemy Within  100000.0
# 2295            InfantRisk Center HCP    1000.0
# 2401          Diabetes & Diet Tracker    1000.0
# 2289   Critical Care Paramedic Review    1000.0

# %%
plt.figure(figsize=(20,12));
plt.pie(top10PaidApps_df.Installs, labels=top10PaidApps_df.App, autopct='%1.1f%%', startangle=0);
plt.title('Top Expensive Apps Distribution',size = 20);
plt.show()

# %%
#What are the top 5 reviewed apps?
top_rev =ud_df.groupby(by=['App', 'Category', 'Rating'])[['Reviews']].sum().reset_index()
top_rev= top_rev.sort_values(by=['Reviews'], ascending=False)
top_rev.head(5)
# Out:
#                                     App          Category  Rating   Reviews
# 4949             GollerCepte Live Score            SPORTS     4.2      9992
# 491        Ad Block REMOVER - NEED ROOT             TOOLS     3.3       999
# 7972                SnipSnap Coupon App          SHOPPING     4.2  99759975
# 8776  US Open Tennis Championships 2018            SPORTS     4.0  99719971
# 3492                         DreamTrips  TRAVEL_AND_LOCAL     4.7      9971

# %%
#What are the top 5 expensive apps?
expensive_app = ud_df.sort_values(by=['Price'], ascending=False)
expensive_app.head(5)
# Out:
#                                  App            Category  Rating Reviews  \
# 9294               EF Lens Simulator         PHOTOGRAPHY     4.4       2
# 3441                    BIG Launcher     PERSONALIZATION     4.3     881
# 9409              Vital Tones EI Pro  HEALTH_AND_FITNESS     4.4       2
# 2295           InfantRisk Center HCP             MEDICAL     2.6      41
# 2289  Critical Care Paramedic Review             MEDICAL     4.4      17
#
#       Size  Installs  Type Price Content Rating            Genres  \
# 9294   33M     100.0  Paid  9.99       Everyone       Photography
# 3441  5.9M   10000.0  Paid  9.99       Everyone   Personalization
# 9409   85M      50.0  Paid  9.99       Everyone  Health & Fitness
# 2295   14M    1000.0  Paid  9.99       Everyone           Medical
# 2289  1.8M    1000.0  Paid  9.99   Everyone 10+           Medical
#
#            Last Updated Current Ver   Android Ver
# 9294  February 27, 2017     2.8.3.1    2.2 and up
# ...

# %%
#Which 5 apps from the 'FAMILY' category are having the lowest rating?
lowest_family = ud_df[ud_df['Category'] == 'FAMILY']
lowest_family = lowest_family.sort_values(by=['Rating'], ascending=True)
lowest_family.head(5)
# Out:
#                                   App Category  Rating Reviews  Size  \
# 4127                Speech Therapy: F   FAMILY     1.0       1   16M
# 10324  FE Mechanical Engineering Prep   FAMILY     1.0       2   21M
# 5978    Truck Driving Test Class 3 BC   FAMILY     1.0       1  2.0M
# 4905          AC REMOTE UNIVERSAL-PRO   FAMILY     1.6     402  1.7M
# 6135                        BG TV App   FAMILY     1.7       6  2.9M
#
#        Installs  Type Price Content Rating         Genres       Last Updated  \
# 4127       10.0  Paid  2.99       Everyone      Education    October 7, 2016
# 10324    1000.0  Free     0       Everyone      Education      July 27, 2018
# 5978       50.0  Paid  1.49       Everyone      Education      April 9, 2012
# 4905   100000.0  Free     0       Everyone  Entertainment  December 11, 2015
# 6135      100.0  Free     0       Everyone  Entertainment  December 21, 2017
#
#       Current Ver   Android Ver
# 4127          1.0  2.3.3 and up
# ...

# %%
# plot the graphs of reviews, size, installs and price per rating
rating_df = ud_df.groupby('Rating')

fig, axes = plt.subplots(1, 4, figsize=(10, 6))

axes[0].plot(ud_df['Rating'], ud_df['Reviews'])
axes[0].set_xlabel('Rating')
axes[0].set_ylabel('Reviews')
axes[0].set_title('Reviews Per Rating')

# axes[1].plot(ud_df['Rating'], ud_df['Size'])
# axes[1].set_xlabel('Rating')
# axes[1].set_ylabel('Size')
# axes[1].set_title('Size Per Rating')

# axes[2].plot(ud_df['Rating'], ud_df['Installs'], 'g')
# axes[2].set_xlabel('Rating')
# axes[2].set_ylabel('Installs (e+10)')
# axes[2].set_title('Installs Per Rating')

# axes[3].plot(ud_df['Rating'], ud_df['Price'], 'k')
# axes[3].set_xlabel('Rating')
# axes[3].set_ylabel('Price')
# axes[3].set_title('Price Per Rating')

plt.tight_layout(pad=2)
plt.show()

# %%
rating_df = ud_df.groupby('Rating')

fig, axes = plt.plot( figsize=(10, 6))

axes[0].plot(ud_df['Rating'], ud_df['Reviews'])
axes[0].set_xlabel('Rating')
axes[0].set_ylabel('Reviews')
axes[0].set_title('Reviews Per Rating')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-79-e1804a312b29> in <module>
#       1 rating_df = ud_df.groupby('Rating')
#       2
# ----> 3 fig, axes = plt.plot( figsize=(10, 6))
#       4
#       5 axes[0].plot(ud_df['Rating'], ud_df['Reviews'])
#
# ValueError: not enough values to unpack (expected 2, got 0)

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 6))  # define the figure and subplots
axes = axes.ravel()  # array to 1D
dfg = ud_df.groupby('Rating')  # get data for each unique value in the first column
colors = ['tab:blue', 'tab:orange', 'tab:green']  # list of colors for each subplot, otherwise all subplots will be one color

for (group, data), color, ax in zip(dfg, colors, axes):
    data.plot(kind='density', ax=ax, color=color, title=group, legend=False)

fig.delaxes(axes[3])  # delete the empty subplot
fig.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-70-8ee4163cffa2> in <module>
#       5
#       6 for (group, data), color, ax in zip(dfg, colors, axes):
# ----> 7     data.plot(kind='density', ax=ax, color=color, title=group, legend=False)
#       8
#       9 fig.delaxes(axes[3])  # delete the empty subplot
#
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
#     974     __call__.__doc__ = __doc__
#
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
# ...

# %%
# application type distribution(type vs number of apps)
plt.figure(figsize=(10, 5))
sns.countplot(ud_df['Type'])
plt.title('Type Distribution')
plt.ylabel('Number of Apps')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
